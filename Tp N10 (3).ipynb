# %%
areas = pd.read_csv("area_protegida.csv")

# %% [markdown]
# 1. carga y exploracion general

# %%
 eaareas.head(5)
# Out:
#          lat        lng  gid entidad          objeto  \
# 0 -53.546655 -68.041297  362   falso  Área protegida
# 1 -31.404445 -64.357709  157   falso  Área protegida
# 2 -32.245004 -60.734423  169   falso  Área protegida
# 3 -26.031780 -54.418743   47   falso  Área protegida
# 4 -26.402258 -65.680992  206   falso  Área protegida
#
#                                                  fna  \
# 0  Sitio RAMSAR y Reserva Hemisférica Costa Atlán...
# 1            Reserva Natural de la Defensa La Calera
# 2                      Sitio Ramsar Delta del Parana
# 3   Parque Natural Municipal Lote C Huerto Municipal
# 4              Parque Provincial Cumbres Calchaquíes
#
#                                   gna                                  nam  \
# 0  Sitio RAMSAR y Reserva Hemisférica  Costa Atlántica de Tierra del Fuego
# 1       Reserva Natural de la Defensa                            La Calera
# 2                        Sitio Ramsar                     Delta del Parana
# 3            Parque Natural Municipal              Lote C Huerto Municipal
# 4                   Parque Provincial                  Cumbres Calchaquíes
#
#    tap  jap  caa                                     fdc    sag     area
# 0    2    2   17      SIB/IGN/Ley Provincial Nº 415/1998    IGN   762166
# 1    2    2   17  SIB/IGN/Protocolo adicional Nº 05/2009    IGN   136225
# 2    2    2   17                                     NaN  MAyDS  2430979
# 3    1    4   17            SIB/IGN/Disposición Nº 45/95    IGN      955
# 4    1    3   17                                     NaN    IGN   706222

# %% [markdown]
# viendo las primeras 5 columnas de Areas Protegidas, podemos notar como las primeras filas muestran los valores: de Latitud y Longitud para calcular y saber donde se ubican las zonas, luego la fila Gid con valores no decimales, Entidad hace referencia al objeto geografico, fna que muestra el nombre del sitio de la area protegida, luego esta Gna que muestra el nombre de la "provincia" donde se ubica. luego se muestra informaciona dicional donde Tap es el "tipo de area" y Jap es "Jurisdiccion". y de ultimo tenemos la fila Caa que muestra el tipo de certificacion

# %% [markdown]
# 2. Estructura y tipos de datos

# %%
areas.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   lat      395 non-null    float64
#  1   lng      395 non-null    float64
#  2   gid      395 non-null    int64
#  3   entidad  395 non-null    str
#  4   objeto   395 non-null    str
#  5   fna      395 non-null    str
#  6   gna      395 non-null    str
#  7   nam      395 non-null    str
#  8   tap      395 non-null    int64
#  9   jap      395 non-null    int64
#  10  caa      395 non-null    int64
#  11  fdc      336 non-null    str
#  12  sag      394 non-null    str
#  13  area     395 non-null    int64
# dtypes: float64(2), int64(5), str(7)
# memory usage: 43.3 KB

# %% [markdown]
# latencia y longitud son datos decimales para almacenar informacion no enteros,

# %% [markdown]
# gid almacena numeros enteros

# %% [markdown]
# como entidad es el valor del tipo de geografia de la zona, esta marcada con strings que representan true y false

# %% [markdown]
# objeto es un string que muestra informacion sobre cual area esta protegida

# %% [markdown]
# fna es un string que muestra el nombre de la provincia donde se ubica el area protegida

# %% [markdown]
# gna es el string que indica cual es el tipo de objeto de la area restringida como ejemplo: establecimiento o rio

# %% [markdown]
# PARTE 2

# %% [markdown]
# 1. sabemos que jurisdiccion y tipo de area nos muestran informacion de las areas protegidas.
#
#    Jurisdiccion nos muestra la autoridad de un area, y Tipo de area nos muestra el detalles de      la area especifica.

# %%
c1 = areas[(areas["jap"] == 2)&(areas["tap"] == 1)].shape[0]

c1
# Out:
# 41

# %% [markdown]
# 2. podemos saber la ubicacion de una areas protegidas por esta columna Area he incluso podemos buscar informacion mas precisa.

# %%
g = areas[areas["area"] >= 20000000]
g["area"]
# Out:
# 33     25855332
# 34     30740644
# 40     58234860
# 62     30553073
# 341    23573774
# Name: area, dtype: int64

# %% [markdown]
# 3.
# entonces sabemos que jap muestra las jurisdiccion de las areas, hasta se podrian contar cada una de estas jurisdicciones, y visualizarlas para comparar cada una!

# %%
count = areas["jap"].value_counts()
grafico = px.pie(data_frame = count, values = count.values, names = count.index, title = "valores de juri")
grafico.show()

# %% [markdown]
# 4.
# ¿sabian que gna muestra parte del nombre geografico de las areas protegidas?
# nos da la oportunidad de buscar las que necesitamos y identificarlas

# %%
nomb = areas[areas["gna"] == "Parque Natural Municipal"]
nomb
# Out:
#            lat        lng  gid entidad          objeto  \
# 3   -26.031780 -54.418743   47   falso  Área protegida
# 28  -27.402324 -55.203168  102   falso  Área protegida
# 86  -26.021745 -54.610589   54   falso  Área protegida
# 115 -34.468699 -58.494295   90   falso  Área protegida
# 144 -25.594299 -54.576966  122   falso  Área protegida
#
#                                                   fna  \
# 3    Parque Natural Municipal Lote C Huerto Municipal
# 28         Parque Natural Municipal Paraje los Indios
# 86                    Parque Natural Municipal Yarará
# 115             Parque Natural Municipal Ribera Norte
# 144       Parque Natural Municipal Luis Honorio Rolón
#
#                           gna                      nam  tap  jap  caa  \
# 3    Parque Natural Municipal  Lote C Huerto Municipal    1    4   17
# 28   Parque Natural Municipal        Paraje los Indios    1    4   17
# 86   Parque Natural Municipal                   Yarará    1    4   17
# 115  Parque Natural Municipal             Ribera Norte    2    4   17
# 144  Parque Natural Municipal       Luis Honorio Rolón    1    4   17
#
#                                            fdc    sag  area
# 3                 SIB/IGN/Disposición Nº 45/95    IGN   955
# 28                                         NaN  MAyDS   206
# 86       SIB/IGN/Ordenaza Municipal Nº 24/1995    IGN   104
# 115         IGN/Portal Web de la Municipalidad    IGN   140
# 144  SIB/IGN/Ordenanza Municipal Nº 27-20/1996    IGN   134

# %% [markdown]
# 5.
# entonces, si con el codigo anterior podemos llamar a los nombres geograficos de las areas, entonces tambien podria funcionar con los demas tipos de informacion que conforman estos tipos de nombres de areas geograficas! como ejemplo, identificar el nombre geografico individual de un objeto determinado

# %%
nomb = areas[areas["nam"] == "Monte Loayza"]
nomb
# Out:
#           lat        lng  gid entidad          objeto  \
# 48 -47.082512 -66.326626   22   falso  Área protegida
# 68 -47.088903 -66.332360   36   falso  Área protegida
#
#                                     fna                     gna           nam  \
# 48  Área de Uso Científico Monte Loayza  Área de Uso Científico  Monte Loayza
# 68      Reserva Provincial Monte Loayza      Reserva Provincial  Monte Loayza
#
#     tap  jap  caa                                        fdc  sag    area
# 48    2    3   17  SIB/IGN/Disposición Provincial Nº 14/1989  IGN  124095
# 68    2    3   17            SIB/IGN/Ley Provincial Nº 2.828  IGN   76062

# %% [markdown]
# 6.
# ¿sabian que la informacion sag muestra el nombre de la autoridad responsable de la informacion utilizada?
# eso me hace preguntar: ¿cual autoridad tiene mas informacion utilizada?

# %%
h = areas["sag"].head(5).value_counts()
px.bar(data_frame = h, x = h.values, y = h.index, title = "barra de sag").show()

# %% [markdown]
# 7.
# al importar folium, podriamos navegar en un mapa lo que nosotros le mandamos a los comandos a hacer.
#
# seria interesante saber donde se ubican los lugares privados de jurisdiccion

# %%
g = areas[areas["jap"] == 5]

mapa = mapp.Map(
    location=[g["lat"].mean(), g["lng"].mean()],
    zoom_start=4
)

for _, fila in g.iterrows():

    mapp.CircleMarker(
        location=[fila["lat"], fila["lng"]],
        radius=6,
        color=colors.get(fila["jap"], "cyan"),
        popup=fila["nam"]
    ).add_to(mapa)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c71b4e5a6a1df149582096083cb48a0e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c71b4e5a6a1df149582096083cb48a0e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c71b4e5a6a1df149582096083cb48a0e = L.map(
#                 &quot;map_c71b4e5a6a1df149582096083cb48a0e&quot;,
#                 {
#                     center: [-27.58417376734844, -58.31352961242311],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_51b73a12fc33b4d23abe4681969b6b26 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_51b73a12fc33b4d23abe4681969b6b26.addTo(map_c71b4e5a6a1df149582096083cb48a0e);
#
#
#             var circle_marker_17cde07e37ca401f0a179b81d423ac64 = L.circleMarker(
#                 [-27.474381564, -55.001868198299],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;cyan&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;cyan&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c71b4e5a6a1df149582096083cb48a0e);
#
#
#         var popup_f0c1e41bd157889199f5bf9f29d7b07c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3d04a12526abe9985d0e62001d70b55 = $(`&lt;div id=&quot;html_b3d04a12526abe9985d0e62001d70b55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ingeniero Barney&lt;/div&gt;`)[0];
#                 popup_f0c1e41bd157889199f5bf9f29d7b07c.setContent(html_b3d04a12526abe9985d0e62001d70b55);
#
#
#
#         circle_marker_17cde07e37ca401f0a179b81d423ac64.bindPopup(popup_f0c1e41bd157889199f5bf9f29d7b07c)
#         ;
#
#
#
#
#             var circle_marker_fe8e6813e27678364bf459aaa79a1ce4 = L.circleMarker(
#                 [-25.990406884, -54.0851772201382],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;cyan&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;cyan&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c71b4e5a6a1df149582096083cb48a0e);
#
#
#         var popup_fead60436c6fa7a5973edb0f159e92e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bcf68cf116ffb7cee3cca777434215bc = $(`&lt;div id=&quot;html_bcf68cf116ffb7cee3cca777434215bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Urugua-í&lt;/div&gt;`)[0];
#                 popup_fead60436c6fa7a5973edb0f159e92e9.setContent(html_bcf68cf116ffb7cee3cca777434215bc);
#
#
#
#         circle_marker_fe8e6813e27678364bf459aaa79a1ce4.bindPopup(popup_fead60436c6fa7a5973edb0f159e92e9)
#         ;
#
#
#
#
#             var circle_marker_1d4db3c98f23b1cc675f15b280cdb7b3 = L.circleMarker(
#                 [-26.3359488299999, -54.3738473193673],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;cyan&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;cyan&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c71b4e5a6a1df149582096083cb48a0e);
#
#
#         var popup_550749c9b42506ac9401ba56bb060905 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f79c51559b5f8bae29f5ae90f721faa0 = $(`&lt;div id=&quot;html_f79c51559b5f8bae29f5ae90f721faa0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lapacho Cué&lt;/div&gt;`)[0];
#                 popup_550749c9b42506ac9401ba56bb060905.setContent(html_f79c51559b5f8bae29f5ae90f721faa0);
#
#
#
#         circle_marker_1d4db3c98f23b1cc675f15b280cdb7b3.bindPopup(popup_550749c9b42506ac9401ba56bb060905)
#         ;
#
#
#
#
#             var circle

# %% [markdown]
# 8.
# como podrias optener la informacion de jurisdiccion que esten disponibles?

# %%
c1 = areas[(areas["jap"] != -1)&(areas["jap"] != 0)]
c1
# Out:
#            lat        lng  gid entidad          objeto  \
# 0   -53.546655 -68.041297  362   falso  Área protegida
# 1   -31.404445 -64.357709  157   falso  Área protegida
# 2   -32.245004 -60.734423  169   falso  Área protegida
# 3   -26.031780 -54.418743   47   falso  Área protegida
# 4   -26.402258 -65.680992  206   falso  Área protegida
# ..         ...        ...  ...     ...             ...
# 387 -30.379778 -62.810767  387   falso  Área protegida
# 388 -30.705936 -62.597763  390   falso  Área protegida
# 390 -41.498783 -64.984633  389   falso  Área protegida
# 391 -27.180310 -58.690677  392   falso  Area Protegida
# 392 -30.371404 -62.793679  391   falso  Área protegida
#
#                                                    fna  \
# 0    Sitio RAMSAR y Reserva Hemisférica Costa Atlán...
# 1              Reserva Natural de la Defensa La Calera
# 2                        Sitio Ramsar Delta del Parana
# 3     Parque Natural Municipal Lote C Huerto Municipal
# 4                Parque Provincial Cumbres Calchaquíes
# ..                                                 ...
# 387  Sitios RAMSAR y Reserva Provincial de Uso Múlt...
# 388                           Parque Nacional Ansenuza
# 390                       Parque Nacional Islote Lobos
# 391                   Parque Nacional Laguna El Palmar
# 392                         Reserva Nacional  Ansenuza
#
#                                                    gna  \
# 0                   Sitio RAMSAR y Reserva Hemisférica
# 1                        Reserva Natural de la Defensa
# 2                                         Sitio Ramsar
# 3                             Parque Natural Municipal
# 4                                    Parque Provincial
# ..                                                 ...
# 387  Sitios RAMSAR y Reserva Provincial de Uso Múltipl
# 388                                    Parque Nacional
# 390                                    Parque Nacional
# 391                                    Parque Nacional
# 392                                   Reserva Nacional
#
#                                                 nam  tap  jap  caa  \
# 0               Costa Atlántica de Tierra del Fuego    2    2   17
# 1                                         La Calera    2    2   17
# 2                                  Delta del Parana    2    2   17
# 3                           Lote C Huerto Municipal    1    4   17
# 4                               Cumbres Calchaquíes    1    3   17
# ..                                              ...  ...  ...  ...
# 387  Bañados del Río Dulce y Laguna de Mar Chiquita    2    2   17
# 388                                        Ansenuza    1    2   17
# 390                                   Islotes Lobos    1    2   17
# 391                                Laguna El Palmar    1    2   17
# 392                                        Ansenuza    2    2   17
#
#                                           fdc    sag      area
# 0          SIB/IGN/Ley Provincial Nº 415/1998    IGN    762166
# 1      SIB/IGN/Protocolo adicional Nº 05/2009    IGN    136225
# 2                                         NaN  MAyDS   2430979
# 3                SIB/IGN/Disposición Nº 45/95    IGN       955
# 4                                         NaN    IGN    706222
# ..                                        ...    ...       ...
# 387  SIB/IGN/Decreto Provincial N° 3.215/1994    IGN  10726532
# 388                                 Ley 27673    IGN   1776194
# 390  SIB/IGN/Decreto Provincial Nº 1.402/1977    IGN    195383
# 391                                 Ley 27707    IGN     55535
# 392                                 Ley 27673    IGN   4839670
#
# [390 rows x 14 columns]

# %% [markdown]
# 9.
#     queremos saber el mapa de los parques que cuenten como una area municipal

# %%
g = areas[(areas["tap"] == 1)&(areas["jap"] == 4)]

mapa = mapp.Map(
    location=[g["lat"].mean(), g["lng"].mean()],
    zoom_start=4
)

for _, fila in g.iterrows():

    mapp.CircleMarker(
        location=[fila["lat"], fila["lng"]],
        radius=6,
        popup=fila["nam"]
    ).add_to(mapa)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_845bc73d5c5baa82f004fe2d43c84a06 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_845bc73d5c5baa82f004fe2d43c84a06&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_845bc73d5c5baa82f004fe2d43c84a06 = L.map(
#                 &quot;map_845bc73d5c5baa82f004fe2d43c84a06&quot;,
#                 {
#                     center: [-26.315923565642816, -56.56858505506773],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4083057ef8d3198ff4d7b9ec54737529 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4083057ef8d3198ff4d7b9ec54737529.addTo(map_845bc73d5c5baa82f004fe2d43c84a06);
#
#
#             var circle_marker_4975a741c16bab1d8809f986e116e2e4 = L.circleMarker(
#                 [-26.0317796969999, -54.4187433829442],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_845bc73d5c5baa82f004fe2d43c84a06);
#
#
#         var popup_f394732eff6af3a457e7b0f917d65370 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_392523548ecd182f267ab64612b918a9 = $(`&lt;div id=&quot;html_392523548ecd182f267ab64612b918a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lote C Huerto Municipal&lt;/div&gt;`)[0];
#                 popup_f394732eff6af3a457e7b0f917d65370.setContent(html_392523548ecd182f267ab64612b918a9);
#
#
#
#         circle_marker_4975a741c16bab1d8809f986e116e2e4.bindPopup(popup_f394732eff6af3a457e7b0f917d65370)
#         ;
#
#
#
#
#             var circle_marker_f4721a17fc44ab4a86941946865d82c0 = L.circleMarker(
#                 [-27.4023237999999, -55.2031675342914],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_845bc73d5c5baa82f004fe2d43c84a06);
#
#
#         var popup_d0cfcab839a6ee64329967b89b713fce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_294b4ae46fe3cff65a48c293e1ea4a76 = $(`&lt;div id=&quot;html_294b4ae46fe3cff65a48c293e1ea4a76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Paraje los Indios&lt;/div&gt;`)[0];
#                 popup_d0cfcab839a6ee64329967b89b713fce.setContent(html_294b4ae46fe3cff65a48c293e1ea4a76);
#
#
#
#         circle_marker_f4721a17fc44ab4a86941946865d82c0.bindPopup(popup_d0cfcab839a6ee64329967b89b713fce)
#         ;
#
#
#
#
#             var circle_marker_5b3a18264f30c328228375d574915365 = L.circleMarker(
#                 [-26.0217449934999, -54.6105887790241],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_845bc73d5c5baa82f004fe2d43c84a06);
#
#
#         var popup_b17c8804e1e97920b91f3baf049efc8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2295a9cdba81c49efd20b27c3b86d7f4 = $(`&lt;div id=&quot;html_2295a9cdba81c49efd20b27c3b86d7f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Yarará&lt;/div&gt;`)[0];
#                 popup_b17c8804e1e97920b91f3baf049efc8e.setContent(html_2295a9cdba81c49efd20b27c3b86d7f4);
#
#
#
#         circle_marker_5b3a18264f30c328228375d574915365.bindPopup(popup_b17c8804e1e97920b91f3baf049efc8e)
#         ;

# %% [markdown]
# 10. el grafico de lineas nos pueden ayudar a identificar el orden de valores de informacion, como en este caso seria jurisdiccion

# %%
g = areas["jap"].value_counts()
px.line(data_frame = g, x = g.values, y = g.index, title = "").show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 g = areas["jap"].value_counts()
# ----> 2 px.line(data_frame = g, x = g.values, y = g.index, title = "").show()
#
# NameError: name 'px' is not defined
