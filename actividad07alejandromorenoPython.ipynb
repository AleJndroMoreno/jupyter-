# %%
import pandas as pd

# %%
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 4.9 MB/s eta 0:00:005.1 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 4.4 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...

# %%
import pandas as pd

# %%
lagos = pd.read_csv("lagos_arg.csv")

# %%
lagos
# Out:
#                     Nombre                                          Ubicación  \
# 0           Lago Argentino                                         Santa Cruz
# 1              Lago Viedma                                         Santa Cruz
# 2        Lago Nahuel Huapi                                Río Negro / Neuquén
# 3             Lago Musters                                             Chubut
# 4             Lago Cardiel                                         Santa Cruz
# 5             Lago Epecuén                                       Buenos Aires
# 6          Lago Pellegrini                                          Río Negro
# 7             Lago Strobel                                         Santa Cruz
# 8             Lago Fontana                                             Chubut
# 9       Lago Huechulafquen                                            Neuquén
# 10             Lago Traful                                            Neuquén
# ...

# %% [markdown]
# ¿Qué columnas tienen valores categorizados que permiten calcular frecuencias con value_counts?

# %%
print(lagos.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Nombre                  52 non-null     str
#  1   Ubicación               52 non-null     str
#  2   Superficie (km²)        52 non-null     int64
#  3   Profundidad máxima (m)  15 non-null     float64
#  4   Profundidad media (m)   22 non-null     float64
#  5   Coordenadas             52 non-null     str
#  6   Sup Tamaño              52 non-null     str
#  7   Latitud en GMS          52 non-null     str
#  8   Longitud en GMS         52 non-null     str
#  9   Latitud en GD           52 non-null     float64
#  10  Longitud en GD          52 non-null     float64
# dtypes: float64(4), int64(1), str(6)
# memory usage: 4.6 KB
# None

# %% [markdown]
# ¿Qué diferencia hay entre las columnas?:

# %% [markdown]
# respuesta: coordenadas,  Latitud en GMS y Longitud en GMS son del tipo objeto (object) con datos de tipo GMS mientras que latitud y lng pertenecen al tipo float (float64) con datos de tipos decimales

# %%
print(lagos.head())
# Out:
#               Nombre            Ubicación  Superficie (km²)  \
# 0     Lago Argentino           Santa Cruz              1435
# 1        Lago Viedma           Santa Cruz              1166
# 2  Lago Nahuel Huapi  Río Negro / Neuquén               540
# 3       Lago Musters               Chubut               427
# 4       Lago Cardiel           Santa Cruz               358
#
#    Profundidad máxima (m)  Profundidad media (m)            Coordenadas  \
# 0                   500.0                  150.0  50°14'53"S 72°38'43"O
# 1                     NaN                    NaN  49°37'27"S 72°29'42"O
# 2                   464.0                  157.0  40°51'16"S 71°36'58"O
# 3                    39.0                   20.0  45°24'53"S 69°11'52"O
# 4                     NaN                   49.0   48°55'3"S 71°12'53"O
#
#   Sup Tamaño Latitud en GMS Longitud en GMS  Latitud en GD  Longitud en GD
# 0     grande     50°14'53"S      72°38'43"O     -50.248056      -72.645278
# ...

# %% [markdown]
# ¿Qué columnas tienen datos faltantes?

# %% [markdown]
# respuesta: Los datos decimales de profundidad maxima con resultado NaN en la columna 1 y 4, profundidad media con resultado NaN en columna 1

# %%
print(lagos.head())
# Out:
#               Nombre            Ubicación  Superficie (km²)  \
# 0     Lago Argentino           Santa Cruz              1435
# 1        Lago Viedma           Santa Cruz              1166
# 2  Lago Nahuel Huapi  Río Negro / Neuquén               540
# 3       Lago Musters               Chubut               427
# 4       Lago Cardiel           Santa Cruz               358
#
#    Profundidad máxima (m)  Profundidad media (m)            Coordenadas  \
# 0                   500.0                  150.0  50°14'53"S 72°38'43"O
# 1                     NaN                    NaN  49°37'27"S 72°29'42"O
# 2                   464.0                  157.0  40°51'16"S 71°36'58"O
# 3                    39.0                   20.0  45°24'53"S 69°11'52"O
# 4                     NaN                   49.0   48°55'3"S 71°12'53"O
#
#   Sup Tamaño Latitud en GMS Longitud en GMS  Latitud en GD  Longitud en GD
# 0     grande     50°14'53"S      72°38'43"O     -50.248056      -72.645278
# ...

# %% [markdown]
# ¿Cuántas filas y columnas tiene el dataset?

# %% [markdown]
# Respuesta: filas: 11, columnas: 15

# %%
print(lagos.value_counts())
# Out:
# Nombre             Ubicación            Superficie (km²)  Profundidad máxima (m)  Profundidad media (m)  Coordenadas            Sup Tamaño  Latitud en GMS  Longitud en GMS  Latitud en GD  Longitud en GD
# Lago Argentino     Santa Cruz           1435              500.0                   150.0                  50°14'53"S 72°38'43"O  grande      50°14'53"S      72°38'43"O       -50.248056     -72.645278        1
# Lago Nahuel Huapi  Río Negro / Neuquén  540               464.0                   157.0                  40°51'16"S 71°36'58"O  grande      40°51'16"S      71°36'58"O       -40.854444     -71.616111        1
# Lago Musters       Chubut               427               39.0                    20.0                   45°24'53"S 69°11'52"O  grande      45°24'53"S      69°11'52"O       -45.414722     -69.197778        1
# ...

# %% [markdown]
# Cuáles son los nombres de las columnas?

# %% [markdown]
# Nombre, Ubicación, Superficie (km²), Profundidad máxima (m),  Profundidad media (m), Coordenadas, Sup Tamaño, Latitud en GMS  Longitud en GMS, lat, lng

# %%
print(lagos.value_counts())
# Out:
# Nombre             Ubicación            Superficie (km²)  Profundidad máxima (m)  Profundidad media (m)  Coordenadas            Sup Tamaño  Latitud en GMS  Longitud en GMS  Latitud en GD  Longitud en GD
# Lago Argentino     Santa Cruz           1435              500.0                   150.0                  50°14'53"S 72°38'43"O  grande      50°14'53"S      72°38'43"O       -50.248056     -72.645278        1
# Lago Nahuel Huapi  Río Negro / Neuquén  540               464.0                   157.0                  40°51'16"S 71°36'58"O  grande      40°51'16"S      71°36'58"O       -40.854444     -71.616111        1
# Lago Musters       Chubut               427               39.0                    20.0                   45°24'53"S 69°11'52"O  grande      45°24'53"S      69°11'52"O       -45.414722     -69.197778        1
# ...

# %% [markdown]
# ¿Qué tipos de datos tiene cada columna?

# %% [markdown]
# Respuesta:
# Nombre: object
# ubicación: object
# Superficie (km²): int
# profundidad maxima: float
# profundidad media: float
# Coordenadas: object
# Sup tamaño: object
# Latitud en GMS: object
# longitud en GMS: object
# lat: float
# lng: float

# %%
print(lagos.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Nombre                  52 non-null     str
#  1   Ubicación               52 non-null     str
#  2   Superficie (km²)        52 non-null     int64
#  3   Profundidad máxima (m)  15 non-null     float64
#  4   Profundidad media (m)   22 non-null     float64
#  5   Coordenadas             52 non-null     str
#  6   Sup Tamaño              52 non-null     str
#  7   Latitud en GMS          52 non-null     str
#  8   Longitud en GMS         52 non-null     str
#  9   Latitud en GD           52 non-null     float64
#  10  Longitud en GD          52 non-null     float64
# dtypes: float64(4), int64(1), str(6)
# memory usage: 4.6 KB
# None

# %% [markdown]
# Muestra las primeras 5 filas del dataset.

# %%
print(lagos.head())
# Out:
#               Nombre            Ubicación  Superficie (km²)  \
# 0     Lago Argentino           Santa Cruz              1435
# 1        Lago Viedma           Santa Cruz              1166
# 2  Lago Nahuel Huapi  Río Negro / Neuquén               540
# 3       Lago Musters               Chubut               427
# 4       Lago Cardiel           Santa Cruz               358
#
#    Profundidad máxima (m)  Profundidad media (m)            Coordenadas  \
# 0                   500.0                  150.0  50°14'53"S 72°38'43"O
# 1                     NaN                    NaN  49°37'27"S 72°29'42"O
# 2                   464.0                  157.0  40°51'16"S 71°36'58"O
# 3                    39.0                   20.0  45°24'53"S 69°11'52"O
# 4                     NaN                   49.0   48°55'3"S 71°12'53"O
#
#   Sup Tamaño Latitud en GMS Longitud en GMS  Latitud en GD  Longitud en GD
# 0     grande     50°14'53"S      72°38'43"O     -50.248056      -72.645278
# ...

# %% [markdown]
# ¿Cuántos lagos hay en la provincia de Santa Cruz?

# %%
print(lagos["Ubicación"].value_counts())
# Out:
# Ubicación
# Santa Cruz                                               16
# Neuquén                                                  14
# Chubut                                                   13
# Río Negro                                                 4
# Tierra del Fuego, Antártida e Islas del Atlántico Sur     3
# Río Negro / Neuquén                                       1
# Buenos Aires                                              1
# Name: count, dtype: int64

# %% [markdown]
# ¿Cuántos lagos hay en cada provincia?

# %%
print(lagos["Ubicación"].value_counts())
# Out:
# Ubicación
# Santa Cruz                                               16
# Neuquén                                                  14
# Chubut                                                   13
# Río Negro                                                 4
# Tierra del Fuego, Antártida e Islas del Atlántico Sur     3
# Río Negro / Neuquén                                       1
# Buenos Aires                                              1
# Name: count, dtype: int64

# %% [markdown]
# Crea un gráfico que compare las cantidades de lagos por provincia.

# %%
filt = lagos["Ubicación"]
kj = filt.value_counts()
kj
#plotly.bar(data_frame = kj, x = kj.values, y = kj.index, title = "titulo").show()
# Out:
# Ubicación
# Santa Cruz                                               16
# Neuquén                                                  14
# Chubut                                                   13
# Río Negro                                                 4
# Tierra del Fuego, Antártida e Islas del Atlántico Sur     3
# Río Negro / Neuquén                                       1
# Buenos Aires                                              1
# Name: count, dtype: int64

# %% [markdown]
# Filtra los lagos que pertenecen a la provincia de Neuquén. ¿falta algún lago de Nequén en el filtro?

# %% [markdown]
# Respuesta: faltan:
#
# Lago Nahuel Huapi  Río Negro

# %%
lagos.head(500)
# Out:
#                     Nombre                                          Ubicación  \
# 0           Lago Argentino                                         Santa Cruz
# 1              Lago Viedma                                         Santa Cruz
# 2        Lago Nahuel Huapi                                Río Negro / Neuquén
# 3             Lago Musters                                             Chubut
# 4             Lago Cardiel                                         Santa Cruz
# 5             Lago Epecuén                                       Buenos Aires
# 6          Lago Pellegrini                                          Río Negro
# 7             Lago Strobel                                         Santa Cruz
# 8             Lago Fontana                                             Chubut
# 9       Lago Huechulafquen                                            Neuquén
# 10             Lago Traful                                            Neuquén
# ...

# %%
lagos[lagos["Ubicación"] == "Neuquén"]
# Out:
#                 Nombre Ubicación  Superficie (km²)  Profundidad máxima (m)  \
# 9   Lago Huechulafquen   Neuquén                84                     NaN
# 10         Lago Traful   Neuquén                78                     NaN
# 14        Lago Aluminé   Neuquén                58                   165.0
# 15          Lago Lácar   Neuquén                53                   277.0
# 23         Lago Espejo   Neuquén                40                     NaN
# 27          Lago Lolog   Neuquén                37                     NaN
# 29         Lago Tromen   Neuquén                29                     NaN
# 31        Lago Quillén   Neuquén                26                     NaN
# 34       Lago Moquehue   Neuquén                21                     NaN
# 35     Lago Correntoso   Neuquén                20                     NaN
# 41         Lago Paimún   Neuquén                16                     NaN
# ...

# %% [markdown]
# Filtra los lagos de Chubut con superficie menor a 100 km²

# %%
p = lagos[lagos["Ubicación"] == "Chubut"]
p[p["Superficie (km²)"] < 100].value_counts()
# Out:
# Nombre             Ubicación  Superficie (km²)  Profundidad máxima (m)  Profundidad media (m)  Coordenadas            Sup Tamaño  Latitud en GMS  Longitud en GMS  Latitud en GD  Longitud en GD
# Lago Menéndez      Chubut     58                287.0                   149.0                  42°41'28"S 71°51'45"O  medio       42°41'28"S      71°51'45"O       -42.691111     -71.862500        1
# Lago Puelo         Chubut     47                180.0                   111.0                  42°9'3"S 71°38'59"O    medio       42°9'3"S        71°38'59"O       -42.150833     -71.649722        1
# Lago Futalaufquen  Chubut     42                168.0                   101.0                  42°49'42"S 71°40'31"O  medio       42°49'42"S      71°40'31"O       -42.828333     -71.675278        1
# Lago Rivadavia     Chubut     23                147.0                   104.0                  42°36'39"S 71°39'59"O  medio       42°36'39"S      71°39'59"O       -42.610833     -71.666389        1
# ...

# %%
# !pip install plotly
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 1.7 MB/s eta 0:00:000:00:010:00:01:01
# ...

# %%
import plotly.express as px

# %% [markdown]
# 3. Crea un gráfico que compare los porcentajes de lagos según la categoría de tamaño.

# %%
g = lagos["Sup Tamaño"].value_counts()
g
# Out:
# Sup Tamaño
# medio     25
# chico     14
# grande    13
# Name: count, dtype: int64

# %%
px.pie(data_frame = g, values = g.values, names = g.index, title = "").show()

# %%
mapa = generar_mapa()
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
import folium

# %%
def generar_mapa():
    attr = (
        '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> '
        'contributors, &copy; <a href="https://cartodb.com/attributions">CartoDB</a>'
    )
    
    tiles = 'https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png'
    m = folium.Map(
        location=(-33.457606, -65.346857),
        control_scale=True,
        zoom_start=5,
        name='es',
        tiles=tiles,
        attr=attr
    )
    return m

# %%
def agregar_marcar_lag(row):
    folium.Marker(
        [row['lat'], row['lng']],
        popup=row['Nombre'],
        icon=folium.Icon()
        ).add_to(mapa)
